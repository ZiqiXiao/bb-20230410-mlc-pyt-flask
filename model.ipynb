# %%
import torch
import torch.nn.functional as F
from torch.nn import Linear
from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GraphConv, TopKPooling, global_mean_pool, GCNConv

# %%
dataset = TUDataset(root='data/TUDataset', name='MUTAG')

# %%
# Define your model here
class GCN(torch.nn.Module):
    def __init__(self, n_ftrs, n_cls, hidden_channels):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = GCNConv(n_ftrs, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, n_cls)

    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)

        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. Apply a final classifier
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)
        
        return x

# %%
loader = DataLoader(dataset, batch_size=64, shuffle=True)
n_ftr = dataset.num_node_features
n_cls = dataset.num_classes

model = GCN(n_ftr, n_cls, 64)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()

# %%
# split dataset into train and test
torch.manual_seed(12345)
dataset = dataset.shuffle()
train_dataset = dataset[:int(len(dataset) * 0.8)]
test_dataset = dataset[int(len(dataset) * 0.8):]
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
def train(train_loader):
    model.train()
    
    for data in train_loader:  # Iterate in batches over the training dataset.
        out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
        loss = criterion(out, data.y)  # Compute the loss.
        loss.backward()  # Derive gradients.
        optimizer.step()  # Update parameters based on gradients.
        optimizer.zero_grad()  # Clear gradients.

# %%
def evl(test_loader):
    model.eval()
    
    correct = 0
    for data in test_loader:  # Iterate in batches over the training/test dataset.
        out = model(data.x, data.edge_index, data.batch)  
        pred = out.argmax(dim=1)  # Use the class with highest probability.
        correct += int((pred == data.y).sum())  # Check against ground-truth labels.
    return correct / len(test_loader.dataset)  # Derive ratio of correct predictions.

# %%
epochs = 200
for epoch in range(epochs):
    train(train_loader)
    train_acc = evl(train_loader)
    test_acc = evl(test_loader)
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# Epoch: 000, Train Acc: 0.6467, Test Acc: 0.7368
# Epoch: 001, Train Acc: 0.6467, Test Acc: 0.7368
# Epoch: 002, Train Acc: 0.6467, Test Acc: 0.7368
# Epoch: 003, Train Acc: 0.6467, Test Acc: 0.7368
# Epoch: 004, Train Acc: 0.6467, Test Acc: 0.7368
# Epoch: 005, Train Acc: 0.7067, Test Acc: 0.7632
# Epoch: 006, Train Acc: 0.7133, Test Acc: 0.7632
# Epoch: 007, Train Acc: 0.7133, Test Acc: 0.7632
# Epoch: 008, Train Acc: 0.7200, Test Acc: 0.8158
# Epoch: 009, Train Acc: 0.7200, Test Acc: 0.8158
# Epoch: 010, Train Acc: 0.7467, Test Acc: 0.7632
# Epoch: 011, Train Acc: 0.7333, Test Acc: 0.7632
# Epoch: 012, Train Acc: 0.7067, Test Acc: 0.7895
# Epoch: 013, Train Acc: 0.7200, Test Acc: 0.7895
# Epoch: 014, Train Acc: 0.7333, Test Acc: 0.7632
# Epoch: 015, Train Acc: 0.7400, Test Acc: 0.7632
# Epoch: 016, Train Acc: 0.7133, Test Acc: 0.7895
# Epoch: 017, Train Acc: 0.7267, Test Acc: 0.7895
# Epoch: 018, Train Acc: 0.7400, Test Acc: 0.7895
# Epoch: 019, Train Acc: 0.7200, Test Acc: 0.8158
# Epoch: 020, Train Acc: 0.7200, Test Acc: 0.8158
# Epoch: 021, Train Acc: 0.7400, Test Acc: 0.7632
# Epoch: 022, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 023, Train Acc: 0.7467, Test Acc: 0.7632
# Epoch: 024, Train Acc: 0.7400, Test Acc: 0.7632
# Epoch: 025, Train Acc: 0.7467, Test Acc: 0.7632
# Epoch: 026, Train Acc: 0.7000, Test Acc: 0.8421
# Epoch: 027, Train Acc: 0.7533, Test Acc: 0.7632
# Epoch: 028, Train Acc: 0.7467, Test Acc: 0.7632
# Epoch: 029, Train Acc: 0.7467, Test Acc: 0.7632
# Epoch: 030, Train Acc: 0.7667, Test Acc: 0.7895
# Epoch: 031, Train Acc: 0.7533, Test Acc: 0.7632
# Epoch: 032, Train Acc: 0.7467, Test Acc: 0.7632
# Epoch: 033, Train Acc: 0.7400, Test Acc: 0.7632
# Epoch: 034, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 035, Train Acc: 0.7533, Test Acc: 0.8158
# Epoch: 036, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 037, Train Acc: 0.7333, Test Acc: 0.7632
# Epoch: 038, Train Acc: 0.7467, Test Acc: 0.7632
# Epoch: 039, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 040, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 041, Train Acc: 0.7533, Test Acc: 0.7632
# Epoch: 042, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 043, Train Acc: 0.7667, Test Acc: 0.7895
# Epoch: 044, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 045, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 046, Train Acc: 0.7667, Test Acc: 0.8158
# Epoch: 047, Train Acc: 0.7733, Test Acc: 0.8158
# Epoch: 048, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 049, Train Acc: 0.7533, Test Acc: 0.7632
# Epoch: 050, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 051, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 052, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 053, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 054, Train Acc: 0.7800, Test Acc: 0.7895
# Epoch: 055, Train Acc: 0.7733, Test Acc: 0.7895
# Epoch: 056, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 057, Train Acc: 0.7733, Test Acc: 0.7895
# Epoch: 058, Train Acc: 0.7733, Test Acc: 0.7895
# Epoch: 059, Train Acc: 0.7667, Test Acc: 0.7895
# Epoch: 060, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 061, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 062, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 063, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 064, Train Acc: 0.7533, Test Acc: 0.7895
# Epoch: 065, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 066, Train Acc: 0.7533, Test Acc: 0.7632
# Epoch: 067, Train Acc: 0.7667, Test Acc: 0.8158
# Epoch: 068, Train Acc: 0.7800, Test Acc: 0.7895
# Epoch: 069, Train Acc: 0.7800, Test Acc: 0.7895
# Epoch: 070, Train Acc: 0.7667, Test Acc: 0.7895
# Epoch: 071, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 072, Train Acc: 0.7800, Test Acc: 0.7895
# Epoch: 073, Train Acc: 0.7800, Test Acc: 0.7895
# Epoch: 074, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 075, Train Acc: 0.7733, Test Acc: 0.8158
# Epoch: 076, Train Acc: 0.7800, Test Acc: 0.7895
# Epoch: 077, Train Acc: 0.7733, Test Acc: 0.8158
# Epoch: 078, Train Acc: 0.7667, Test Acc: 0.7895
# Epoch: 079, Train Acc: 0.7800, Test Acc: 0.7895
# Epoch: 080, Train Acc: 0.7733, Test Acc: 0.7895
# Epoch: 081, Train Acc: 0.7600, Test Acc: 0.7895
# Epoch: 082, Train Acc: 0.7667, Test Acc: 0.7895
# Epoch: 083, Train Acc: 0.7600, Test Acc: 0.7895
# Epoch: 084, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 085, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 086, Train Acc: 0.7600, Test Acc: 0.7895
# Epoch: 087, Train Acc: 0.7800, Test Acc: 0.8158
# Epoch: 088, Train Acc: 0.7733, Test Acc: 0.7895
# Epoch: 089, Train Acc: 0.7800, Test Acc: 0.8158
# Epoch: 090, Train Acc: 0.7800, Test Acc: 0.7895
# Epoch: 091, Train Acc: 0.7533, Test Acc: 0.7368
# Epoch: 092, Train Acc: 0.7733, Test Acc: 0.7895
# Epoch: 093, Train Acc: 0.7733, Test Acc: 0.7895
# Epoch: 094, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 095, Train Acc: 0.7800, Test Acc: 0.7895
# Epoch: 096, Train Acc: 0.7800, Test Acc: 0.7895
# Epoch: 097, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 098, Train Acc: 0.7733, Test Acc: 0.7895
# Epoch: 099, Train Acc: 0.7733, Test Acc: 0.8158
# Epoch: 100, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 101, Train Acc: 0.7800, Test Acc: 0.8158
# Epoch: 102, Train Acc: 0.7800, Test Acc: 0.7895
# Epoch: 103, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 104, Train Acc: 0.7667, Test Acc: 0.7895
# Epoch: 105, Train Acc: 0.7933, Test Acc: 0.8158
# Epoch: 106, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 107, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 108, Train Acc: 0.7933, Test Acc: 0.8158
# Epoch: 109, Train Acc: 0.7733, Test Acc: 0.7895
# Epoch: 110, Train Acc: 0.7733, Test Acc: 0.7895
# Epoch: 111, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 112, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 113, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 114, Train Acc: 0.7733, Test Acc: 0.7895
# Epoch: 115, Train Acc: 0.8200, Test Acc: 0.7105
# Epoch: 116, Train Acc: 0.7800, Test Acc: 0.7632
# Epoch: 117, Train Acc: 0.7600, Test Acc: 0.7368
# Epoch: 118, Train Acc: 0.7800, Test Acc: 0.8158
# Epoch: 119, Train Acc: 0.7933, Test Acc: 0.7632
# Epoch: 120, Train Acc: 0.7733, Test Acc: 0.7368
# Epoch: 121, Train Acc: 0.7933, Test Acc: 0.8158
# Epoch: 122, Train Acc: 0.8067, Test Acc: 0.7368
# Epoch: 123, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 124, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 125, Train Acc: 0.8200, Test Acc: 0.6842
# Epoch: 126, Train Acc: 0.7733, Test Acc: 0.7368
# Epoch: 127, Train Acc: 0.7733, Test Acc: 0.7105
# Epoch: 128, Train Acc: 0.7800, Test Acc: 0.7632
# Epoch: 129, Train Acc: 0.7867, Test Acc: 0.7895
# Epoch: 130, Train Acc: 0.7933, Test Acc: 0.7895
# Epoch: 131, Train Acc: 0.7933, Test Acc: 0.7895
# Epoch: 132, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 133, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 134, Train Acc: 0.7667, Test Acc: 0.7368
# Epoch: 135, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 136, Train Acc: 0.8267, Test Acc: 0.6579
# Epoch: 137, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 138, Train Acc: 0.7800, Test Acc: 0.7368
# Epoch: 139, Train Acc: 0.7933, Test Acc: 0.6316
# Epoch: 140, Train Acc: 0.7733, Test Acc: 0.7368
# Epoch: 141, Train Acc: 0.7733, Test Acc: 0.7368
# Epoch: 142, Train Acc: 0.7933, Test Acc: 0.7895
# Epoch: 143, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 144, Train Acc: 0.7733, Test Acc: 0.7105
# Epoch: 145, Train Acc: 0.7933, Test Acc: 0.7895
# Epoch: 146, Train Acc: 0.7933, Test Acc: 0.7895
# Epoch: 147, Train Acc: 0.7800, Test Acc: 0.7632
# Epoch: 148, Train Acc: 0.7800, Test Acc: 0.7895
# Epoch: 149, Train Acc: 0.8133, Test Acc: 0.6579
# Epoch: 150, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 151, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 152, Train Acc: 0.8133, Test Acc: 0.6579
# Epoch: 153, Train Acc: 0.7867, Test Acc: 0.7632
# Epoch: 154, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 155, Train Acc: 0.7867, Test Acc: 0.7895
# Epoch: 156, Train Acc: 0.8200, Test Acc: 0.6579
# Epoch: 157, Train Acc: 0.7800, Test Acc: 0.7632
# Epoch: 158, Train Acc: 0.7867, Test Acc: 0.7632
# Epoch: 159, Train Acc: 0.7800, Test Acc: 0.7632
# Epoch: 160, Train Acc: 0.8200, Test Acc: 0.7368
# Epoch: 161, Train Acc: 0.8067, Test Acc: 0.7895
# Epoch: 162, Train Acc: 0.7867, Test Acc: 0.7895
# Epoch: 163, Train Acc: 0.7867, Test Acc: 0.7632
# Epoch: 164, Train Acc: 0.7867, Test Acc: 0.7895
# Epoch: 165, Train Acc: 0.8067, Test Acc: 0.7895
# Epoch: 166, Train Acc: 0.7933, Test Acc: 0.7632
# Epoch: 167, Train Acc: 0.7733, Test Acc: 0.7368
# Epoch: 168, Train Acc: 0.7933, Test Acc: 0.7632
# Epoch: 169, Train Acc: 0.8333, Test Acc: 0.7632
# Epoch: 170, Train Acc: 0.8267, Test Acc: 0.6842
# Epoch: 171, Train Acc: 0.7933, Test Acc: 0.7632
# Epoch: 172, Train Acc: 0.7933, Test Acc: 0.7895
# Epoch: 173, Train Acc: 0.7933, Test Acc: 0.7632
# Epoch: 174, Train Acc: 0.8333, Test Acc: 0.6842
# Epoch: 175, Train Acc: 0.8133, Test Acc: 0.7368
# Epoch: 176, Train Acc: 0.8000, Test Acc: 0.7632
# Epoch: 177, Train Acc: 0.7867, Test Acc: 0.7368
# Epoch: 178, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 179, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 180, Train Acc: 0.7933, Test Acc: 0.7105
# Epoch: 181, Train Acc: 0.7800, Test Acc: 0.7632
# Epoch: 182, Train Acc: 0.8200, Test Acc: 0.6842
# Epoch: 183, Train Acc: 0.8267, Test Acc: 0.7368
# Epoch: 184, Train Acc: 0.7867, Test Acc: 0.7632
# Epoch: 185, Train Acc: 0.8067, Test Acc: 0.7368
# Epoch: 186, Train Acc: 0.7933, Test Acc: 0.7105
# Epoch: 187, Train Acc: 0.7800, Test Acc: 0.7895
# Epoch: 188, Train Acc: 0.7667, Test Acc: 0.7895
# Epoch: 189, Train Acc: 0.8000, Test Acc: 0.7632
# Epoch: 190, Train Acc: 0.8333, Test Acc: 0.7105
# Epoch: 191, Train Acc: 0.8000, Test Acc: 0.7632
# Epoch: 192, Train Acc: 0.8000, Test Acc: 0.7368
# Epoch: 193, Train Acc: 0.8000, Test Acc: 0.7632
# Epoch: 194, Train Acc: 0.8067, Test Acc: 0.7632
# Epoch: 195, Train Acc: 0.8400, Test Acc: 0.7105
# Epoch: 196, Train Acc: 0.8333, Test Acc: 0.7368
# Epoch: 197, Train Acc: 0.8133, Test Acc: 0.7632
# Epoch: 198, Train Acc: 0.8067, Test Acc: 0.7895
# Epoch: 199, Train Acc: 0.8533, Test Acc: 0.7368
